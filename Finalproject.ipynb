# %%
mkdir diabetes
cd diabetes
docker run -p 8787:8787 ...(login to Rstudio through Docker)

Connect to local host through browser (8787:8787)
Similar to HW 10

# %%
Run agent mode (chatgpt) set up agent based AI

AI inside the container

# %%
Set up codax 
QWEN code?
Set up nodejs in our container (ask Chaatgpt)

# %%
Create docker file and putting everything we need in a docker file

# %%
# In Rstudio

FROM rocker/verse
